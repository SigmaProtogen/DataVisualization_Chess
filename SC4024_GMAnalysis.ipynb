# %% [markdown]
# # Grandmaster Geospatial distribution Analysis

# %%
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
gm_df = pd.read_csv("List_of_chess_grandmasters.csv", header=0)
gm_df.sort_values("Title\nYear")
# Out:
#                              Name     FIDE ID        Born     Birthplace  \
# 233            Botvinnik, Mikhail         NaN  1911-08-17       Kuokkala
# 223             Bondarevsky, Igor         NaN  1913-05-12  Rostov-on-Don
# 221            Boleslavsky, Isaac         NaN  1919-06-09    Zolotonosha
# 1718            Ståhlberg, Gideon         NaN  1908-01-26        Angered
# 1543            Rubinstein, Akiba         NaN  1880-12-01       Stawiski
# ...                           ...         ...         ...            ...
# 823                 Khanin, Semen   4111990.0  1999-05-23    Novosibirsk
# 1443                    Pranesh M  35028600.0  2006-08-26      Karaikudi
# 1727    Stefansson, Vignir Vatnar   2308649.0        2003            NaN
# 931            Koustav Chatterjee  25073060.0  2003-07-21        Kolkata
# 179   Berdayes Ason, Dylan Isidro   3516016.0  1998-05-15         Havana
#
#             Died  Title\nYear    Federation Sex  \
# ...
